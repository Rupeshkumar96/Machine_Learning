# %% [markdown]
# ## Linear Regression
# ## Polynomial Regression
# ## Lasso Regression
# ## Ridge Regression

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Handle Outlier
num_values=df.select_dtypes(include=np.number)
for num in num_values:
    q1=df[num].quantile(0.25)
    q3=df[num].quantile(0.75)
    iqr=q3-q1
    ll=q1-1.5*iqr
    ul=q3+1.5*iqr
    outlier=df[(df[num]<ll)|(df[num]>ul)]
    print(f'The outlier of{df[num]} is {len(outlier)}')
    df=df[(df[num]>=ll)|(df[num]<=ul)]
# Out:
# The outlier of0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64 is 240
# The outlier of0       3.0
# 1       5.0
# 2       3.0
# 3       3.0
# 4       4.0
#        ...
# 4595    3.0
# 4596    3.0
# 4597    3.0
# 4598    4.0
# 4599    3.0
# Name: bedrooms, Length: 4600, dtype: float64 is 118
# The outlier of0       1.50
# 1       2.50
# 2       2.00
# 3       2.25
# 4       2.50
#         ...
# 4595    1.75
# 4596    2.50
# 4597    2.50
# 4598    2.00
# 4599    2.50
# Name: bathrooms, Length: 4600, dtype: float64 is 141
# The outlier of0       1340
# 1       3650
# 2       1930
# 3       2000
# 4       1940
#         ...
# 4595    1510
# 4596    1460
# 4597    3010
# 4598    2090
# 4599    1490
# Name: sqft_living, Length: 4600, dtype: int64 is 129
# The outlier of0        7912
# 1        9050
# 2       11947
# 3        8030
# 4       10500
#         ...
# 4595     6360
# 4596     7573
# 4597     7014
# 4598     6630
# 4599     8102
# Name: sqft_lot, Length: 4600, dtype: int64 is 541
# The outlier of0       1.5
# 1       2.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 4595    1.0
# 4596    2.0
# 4597    2.0
# 4598    1.0
# 4599    2.0
# Name: floors, Length: 4600, dtype: float64 is 0
# The outlier of0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4595    0
# 4596    0
# 4597    0
# 4598    0
# 4599    0
# Name: waterfront, Length: 4600, dtype: int64 is 33
# The outlier of0       0
# 1       4
# 2       0
# 3       0
# 4       0
#        ..
# 4595    0
# 4596    0
# 4597    0
# 4598    0
# 4599    0
# Name: view, Length: 4600, dtype: int64 is 460
# The outlier of0       3
# 1       5
# 2       4
# 3       4
# 4       4
#        ..
# 4595    4
# 4596    3
# 4597    3
# 4598    3
# 4599    4
# Name: condition, Length: 4600, dtype: int64 is 6
# The outlier of0       1340
# 1       3370
# 2       1930
# 3       1000
# 4       1140
#         ...
# 4595    1510
# 4596    1460
# 4597    3010
# 4598    1070
# 4599    1490
# Name: sqft_above, Length: 4600, dtype: int64 is 116
# The outlier of0          0
# 1        280
# 2          0
# 3       1000
# 4        800
#         ...
# 4595       0
# 4596       0
# 4597       0
# 4598    1020
# 4599       0
# Name: sqft_basement, Length: 4600, dtype: int64 is 82
# The outlier of0       1955
# 1       1921
# 2       1966
# 3       1963
# 4       1976
#         ...
# 4595    1954
# 4596    1983
# 4597    2009
# 4598    1974
# 4599    1990
# Name: yr_built, Length: 4600, dtype: int64 is 0
# The outlier of0       2005
# 1          0
# 2          0
# 3          0
# 4       1992
#         ...
# 4595    1979
# 4596    2009
# 4597       0
# 4598       0
# 4599       0
# Name: yr_renovated, Length: 4600, dtype: int64 is 0

# %%
df.drop(['date','street','city','statezip','country'],axis=1,inplace=True)

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_pred,y_test)
mae=mean_absolute_error(y_pred,y_test)
r2score=r2_score(y_pred,y_test)
print("Mean Squared Error:",mse)
print("Mean Absolute Error:",mae)
print("R2_Score:",r2score)
print("Root Mean Squared Error:",np.sqrt(mse))
# Out:
# Mean Squared Error: 986921767056.1605
# Mean Absolute Error: 210908.17325013687
# R2_Score: -11.29181278467033
# Root Mean Squared Error: 993439.36254618
